# %% [markdown]
# # Experiment 1: Data Preprocessing and Statistical Analysis
#
# **Objective:**
# To compute statistical measures and understand data distribution
# as part of preprocessing in machine learning.

# %% [markdown]
# ## Dataset Description
# A numeric dataset is used to compute descriptive statistics
# such as mean, median, mode, variance, standard deviation,
# quartiles, and interquartile range.

# %% [markdown]
# ## Conclusion
# Statistical preprocessing helps identify patterns, spread,
# and potential outliers in data before applying ML algorithms.

# %%
import numpy as np
import pandas as pd
from scipy import stats

# %%
data = [12, 15, 20, 20, 25, 30, 35, 40, 40, 40, 45]
data_array = np.array(data)
data_array
# Out:
# array([12, 15, 20, 20, 25, 30, 35, 40, 40, 40, 45])

# %%
mean = np.mean(data_array)
median = np.median(data_array)
mode = stats.mode(data_array, keepdims=True).mode[0]

print("Mean:", mean)
print("Median:", median)
print("Mode:", mode)
# Out:
# Mean: 29.272727272727273
# Median: 30.0
# Mode: 40

# %%
variance = np.var(data_array)
std_dev = np.std(data_array)

print("Variance:", variance)
print("Standard Deviation:", std_dev)
# Out:
# Variance: 119.83471074380166
# Standard Deviation: 10.94690416253845

# %%
q1 = np.percentile(data_array, 25)
q2 = np.percentile(data_array, 50)
q3 = np.percentile(data_array, 75)

iqr = q3 - q1

print("Q1 (25th percentile):", q1)
print("Q2 (Median):", q2)
print("Q3 (75th percentile):", q3)
print("Interquartile Range (IQR):", iqr)
# Out:
# Q1 (25th percentile): 20.0
# Q2 (Median): 30.0
# Q3 (75th percentile): 40.0
# Interquartile Range (IQR): 20.0

# %%
pd.Series(data_array).describe()
# Out:
# count    11.000000
# mean     29.272727
# std      11.481210
# min      12.000000
# 25%      20.000000
# 50%      30.000000
# 75%      40.000000
# max      45.000000
# dtype: float64
